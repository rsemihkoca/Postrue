# %%
from sqlalchemy import create_engine, Column, Integer, String, Boolean, Float, DateTime
from sqlalchemy.ext.declarative import declarative_base
from sqlalchemy.orm import sessionmaker
import datetime
import random

Base = declarative_base()

class Transactions(Base):
    __tablename__ = 'Transactions'

    Datetime = Column(DateTime, primary_key=True)
    Year = Column(Integer, primary_key=True)
    Month = Column(Integer, primary_key=True)
    Day = Column(Integer, primary_key=True)
    ClientId = Column(Integer, primary_key=True)
    ClientName = Column(String)
    BadPosture = Column(Boolean)
    TorsoInclination = Column(Float)
    NeckInclination = Column(Float)

POSTGRESQL_CON_STR = "postgresql+psycopg2://postgres:postgres@127.0.0.1:5432/postgres"
engine = create_engine(POSTGRESQL_CON_STR)
Session = sessionmaker(bind=engine)
session = Session()

start_date = datetime.datetime.now() - datetime.timedelta(days=60)
current_date = start_date

data_to_insert = []

while current_date < datetime.datetime.now():
    num_data_points = random.randint(0, 10)
    
    for _ in range(num_data_points):
        neck_inclination = random.uniform(1, 35)
        torso_inclination = random.uniform(1, 75)
        
        bad_frames = 0
        if neck_inclination >= 40 or torso_inclination >= 10:
            bad_frames += 1
        
        data = {
            "Datetime": current_date,
            "Year": current_date.year,
            "Month": current_date.month,
            "Day": current_date.day,
            "ClientId": 1,
            "ClientName": "admin",
            "BadPosture": bad_frames > 0,
            "TorsoInclination": torso_inclination,
            "NeckInclination": neck_inclination
        }
        
        data_to_insert.append(data)
        
    current_date += datetime.timedelta(days=1)

for data in data_to_insert:
    transaction = Transactions(**data)
    session.add(transaction)

session.commit()
session.close()
# Out:
# /tmp/ipykernel_2916490/686000837.py:7: MovedIn20Warning: The ``declarative_base()`` function is now available as sqlalchemy.orm.declarative_base(). (deprecated since: 2.0) (Background on SQLAlchemy 2.0 at: https://sqlalche.me/e/b8d9)
#   Base = declarative_base()
# /tmp/ipykernel_2916490/686000837.py:63: SAWarning: Identity map already had an identity for (<class '__main__.Transactions'>, (datetime.datetime(2023, 8, 11, 15, 36, 7, 504106), 2023, 8, 11, 1), None), replacing it with newly flushed object.   Are there load operations occurring inside of an event handler within the flush?
#   session.commit()
# /tmp/ipykernel_2916490/686000837.py:63: SAWarning: Identity map already had an identity for (<class '__main__.Transactions'>, (datetime.datetime(2023, 8, 12, 15, 36, 7, 504106), 2023, 8, 12, 1), None), replacing it with newly flushed object.   Are there load operations occurring inside of an event handler within the flush?
#   session.commit()
# /tmp/ipykernel_2916490/686000837.py:63: SAWarning: Identity map already had an identity for (<class '__main__.Transactions'>, (datetime.datetime(2023, 8, 13, 15, 36, 7, 504106), 2023, 8, 13, 1), None), replacing it with newly flushed object.   Are there load operations occurring inside of an event handler within the flush?
#   session.commit()
# /tmp/ipykernel_2916490/686000837.py:63: SAWarning: Identity map already had an identity for (<class '__main__.Transactions'>, (datetime.datetime(2023, 8, 15, 15, 36, 7, 504106), 2023, 8, 15, 1), None), replacing it with newly flushed object.   Are there load operations occurring inside of an event handler within the flush?
#   session.commit()
# /tmp/ipykernel_2916490/686000837.py:63: SAWarning: Identity map already had an identity for (<class '__main__.Transactions'>, (datetime.datetime(2023, 8, 16, 15, 36, 7, 504106), 2023, 8, 16, 1), None), replacing it with newly flushed object.   Are there load operations occurring inside of an event handler within the flush?
#   session.commit()
# /tmp/ipykernel_2916490/686000837.py:63: SAWarning: Identity map already had an identity for (<class '__main__.Transactions'>, (datetime.datetime(2023, 8, 18, 15, 36, 7, 504106), 2023, 8, 18, 1), None), replacing it with newly flushed object.   Are there load operations occurring inside of an event handler within the flush?
#   session.commit()
# /tmp/ipykernel_2916490/686000837.py:63: SAWarning: Identity map already had an identity for (<class '__main__.Transactions'>, (datetime.datetime(2023, 7, 12, 15, 36, 7, 504106), 2023, 7, 12, 1), None), replacing it with newly flushed object.   Are there load operations occurring inside of an event handler within the flush?
#   session.commit()
# /tmp/ipykernel_2916490/686000837.py:63: SAWarning: Identity map already had an identity for (<class '__main__.Transactions'>, (datetime.datetime(2023, 8, 19, 15, 36, 7, 504106), 2023, 8, 19, 1), None), replacing it with newly flushed object.   Are there load operations occurring inside of an event handler within the flush?
#   session.commit()
# /tmp/ipykernel_2916490/686000837.py:63: SAWarning: Identity map already had an identity for (<class '__main__.Transactions'>, (datetime.datetime(2023, 7, 13, 15, 36, 7, 504106), 2023, 7, 13, 1), None), replacing it with newly flushed object.   Are there load operations occurring inside of an event handler within the flush?
#   session.commit()
# /tmp/ipykernel_2916490/686000837.py:63: SAWarning: Identity map already had an identity for (<class '__main__.Transactions'>, (datetime.datetime(2023, 8, 20, 15, 36, 7, 504106), 2023, 8, 20, 1), None), replacing it with newly flushed object.   Are there load operations occurring inside of an event handler within the flush?
#   session.commit()
# /tmp/ipykernel_2916490/686000837.py:63: SAWarning: Identity map already had an identity for (<class '__main__.Transactions'>, (datetime.datetime(2023, 8, 21, 15, 36, 7, 504106), 2023, 8, 21, 1), None), replacing it with newly flushed object.   Are there load operations occurring inside of an event handler within the flush?
#   session.commit()
# /tmp/ipykernel_2916490/686000837.py:63: SAWarning: Identity map already had an identity for (<class '__main__.Transactions'>, (datetime.datetime(2023, 7, 14, 15, 36, 7, 504106), 2023, 7, 14, 1), None), replacing it with newly flushed object.   Are there load operations occurring inside of an event handler within the flush?
#   session.commit()
# /tmp/ipykernel_2916490/686000837.py:63: SAWarning: Identity map already had an identity for (<class '__main__.Transactions'>, (datetime.datetime(2023, 7, 15, 15, 36, 7, 504106), 2023, 7, 15, 1), None), replacing it with newly flushed object.   Are there load operations occurring inside of an event handler within the flush?
#   session.commit()
# /tmp/ipykernel_2916490/686000837.py:63: SAWarning: Identity map already had an identity for (<class '__main__.Transactions'>, (datetime.datetime(2023, 8, 22, 15, 36, 7, 504106), 2023, 8, 22, 1), None), replacing it with newly flushed object.   Are there load operations occurring inside of an event handler within the flush?
#   session.commit()
# /tmp/ipykernel_2916490/686000837.py:63: SAWarning: Identity map already had an identity for (<class '__main__.Transactions'>, (datetime.datetime(2023, 7, 16, 15, 36, 7, 504106), 2023, 7, 16, 1), None), replacing it with newly flushed object.   Are there load operations occurring inside of an event handler within the flush?
#   session.commit()
# /tmp/ipykernel_2916490/686000837.py:63: SAWarning: Identity map already had an identity for (<class '__main__.Transactions'>, (datetime.datetime(2023, 7, 17, 15, 36, 7, 504106), 2023, 7, 17, 1), None), replacing it with newly flushed object.   Are there load operations occurring inside of an event handler within the flush?
#   session.commit()
# /tmp/ipykernel_2916490/686000837.py:63: SAWarning: Identity map already had an identity for (<class '__main__.Transactions'>, (datetime.datetime(2023, 8, 23, 15, 36, 7, 504106), 2023, 8, 23, 1), None), replacing it with newly flushed object.   Are there load operations occurring inside of an event handler within the flush?
#   session.commit()
# /tmp/ipykernel_2916490/686000837.py:63: SAWarning: Identity map already had an identity for (<class '__main__.Transactions'>, (datetime.datetime(2023, 7, 18, 15, 36, 7, 504106), 2023, 7, 18, 1), None), replacing it with newly flushed object.   Are there load operations occurring inside of an event handler within the flush?
#   session.commit()
# /tmp/ipykernel_2916490/686000837.py:63: SAWarning: Identity map already had an identity for (<class '__main__.Transactions'>, (datetime.datetime(2023, 7, 19, 15, 36, 7, 504106), 2023, 7, 19, 1), None), replacing it with newly flushed object.   Are there load operations occurring inside of an event handler within the flush?
#   session.commit()
# /tmp/ipykernel_2916490/686000837.py:63: SAWarning: Identity map already had an identity for (<class '__main__.Transactions'>, (datetime.datetime(2023, 8, 24, 15, 36, 7, 504106), 2023, 8, 24, 1), None), replacing it with newly flushed object.   Are there load operations occurring inside of an event handler within the flush?
#   session.commit()
# /tmp/ipykernel_2916490/686000837.py:63: SAWarning: Identity map already had an identity for (<class '__main__.Transactions'>, (datetime.datetime(2023, 7, 20, 15, 36, 7, 504106), 2023, 7, 20, 1), None), replacing it with newly flushed object.   Are there load operations occurring inside of an event handler within the flush?
#   session.commit()
# /tmp/ipykernel_2916490/686000837.py:63: SAWarning: Identity map already had an identity for (<class '__main__.Transactions'>, (datetime.datetime(2023, 7, 22, 15, 36, 7, 504106), 2023, 7, 22, 1), None), replacing it with newly flushed object.   Are there load operations occurring inside of an event handler within the flush?
#   session.commit()
# /tmp/ipykernel_2916490/686000837.py:63: SAWarning: Identity map already had an identity for (<class '__main__.Transactions'>, (datetime.datetime(2023, 8, 25, 15, 36, 7, 504106), 2023, 8, 25, 1), None), replacing it with newly flushed object.   Are there load operations occurring inside of an event handler within the flush?
#   session.commit()
# /tmp/ipykernel_2916490/686000837.py:63: SAWarning: Identity map already had an identity for (<class '__main__.Transactions'>, (datetime.datetime(2023, 7, 23, 15, 36, 7, 504106), 2023, 7, 23, 1), None), replacing it with newly flushed object.   Are there load operations occurring inside of an event handler within the flush?
#   session.commit()
# /tmp/ipykernel_2916490/686000837.py:63: SAWarning: Identity map already had an identity for (<class '__main__.Transactions'>, (datetime.datetime(2023, 8, 29, 15, 36, 7, 504106), 2023, 8, 29, 1), None), replacing it with newly flushed object.   Are there load operations occurring inside of an event handler within the flush?
#   session.commit()
# /tmp/ipykernel_2916490/686000837.py:63: SAWarning: Identity map already had an identity for (<class '__main__.Transactions'>, (datetime.datetime(2023, 7, 25, 15, 36, 7, 504106), 2023, 7, 25, 1), None), replacing it with newly flushed object.   Are there load operations occurring inside of an event handler within the flush?
#   session.commit()
# /tmp/ipykernel_2916490/686000837.py:63: SAWarning: Identity map already had an identity for (<class '__main__.Transactions'>, (datetime.datetime(2023, 7, 26, 15, 36, 7, 504106), 2023, 7, 26, 1), None), replacing it with newly flushed object.   Are there load operations occurring inside of an event handler within the flush?
#   session.commit()
# /tmp/ipykernel_2916490/686000837.py:63: SAWarning: Identity map already had an identity for (<class '__main__.Transactions'>, (datetime.datetime(2023, 8, 30, 15, 36, 7, 504106), 2023, 8, 30, 1), None), replacing it with newly flushed object.   Are there load operations occurring inside of an event handler within the flush?
#   session.commit()
# /tmp/ipykernel_2916490/686000837.py:63: SAWarning: Identity map already had an identity for (<class '__main__.Transactions'>, (datetime.datetime(2023, 8, 31, 15, 36, 7, 504106), 2023, 8, 31, 1), None), replacing it with newly flushed object.   Are there load operations occurring inside of an event handler within the flush?
#   session.commit()
# /tmp/ipykernel_2916490/686000837.py:63: SAWarning: Identity map already had an identity for (<class '__main__.Transactions'>, (datetime.datetime(2023, 7, 27, 15, 36, 7, 504106), 2023, 7, 27, 1), None), replacing it with newly flushed object.   Are there load operations occurring inside of an event handler within the flush?
#   session.commit()
# /tmp/ipykernel_2916490/686000837.py:63: SAWarning: Identity map already had an identity for (<class '__main__.Transactions'>, (datetime.datetime(2023, 9, 1, 15, 36, 7, 504106), 2023, 9, 1, 1), None), replacing it with newly flushed object.   Are there load operations occurring inside of an event handler within the flush?
#   session.commit()
# /tmp/ipykernel_2916490/686000837.py:63: SAWarning: Identity map already had an identity for (<class '__main__.Transactions'>, (datetime.datetime(2023, 7, 29, 15, 36, 7, 504106), 2023, 7, 29, 1), None), replacing it with newly flushed object.   Are there load operations occurring inside of an event handler within the flush?
#   session.commit()
# /tmp/ipykernel_2916490/686000837.py:63: SAWarning: Identity map already had an identity for (<class '__main__.Transactions'>, (datetime.datetime(2023, 9, 2, 15, 36, 7, 504106), 2023, 9, 2, 1), None), replacing it with newly flushed object.   Are there load operations occurring inside of an event handler within the flush?
#   session.commit()
# /tmp/ipykernel_2916490/686000837.py:63: SAWarning: Identity map already had an identity for (<class '__main__.Transactions'>, (datetime.datetime(2023, 7, 30, 15, 36, 7, 504106), 2023, 7, 30, 1), None), replacing it with newly flushed object.   Are there load operations occurring inside of an event handler within the flush?
#   session.commit()
# /tmp/ipykernel_2916490/686000837.py:63: SAWarning: Identity map already had an identity for (<class '__main__.Transactions'>, (datetime.datetime(2023, 9, 3, 15, 36, 7, 504106), 2023, 9, 3, 1), None), replacing it with newly flushed object.   Are there load operations occurring inside of an event handler within the flush?
#   session.commit()
# /tmp/ipykernel_2916490/686000837.py:63: SAWarning: Identity map already had an identity for (<class '__main__.Transactions'>, (datetime.datetime(2023, 8, 1, 15, 36, 7, 504106), 2023, 8, 1, 1), None), replacing it with newly flushed object.   Are there load operations occurring inside of an event handler within the flush?
#   session.commit()
# /tmp/ipykernel_2916490/686000837.py:63: SAWarning: Identity map already had an identity for (<class '__main__.Transactions'>, (datetime.datetime(2023, 8, 2, 15, 36, 7, 504106), 2023, 8, 2, 1), None), replacing it with newly flushed object.   Are there load operations occurring inside of an event handler within the flush?
#   session.commit()
# /tmp/ipykernel_2916490/686000837.py:63: SAWarning: Identity map already had an identity for (<class '__main__.Transactions'>, (datetime.datetime(2023, 9, 4, 15, 36, 7, 504106), 2023, 9, 4, 1), None), replacing it with newly flushed object.   Are there load operations occurring inside of an event handler within the flush?
#   session.commit()
# /tmp/ipykernel_2916490/686000837.py:63: SAWarning: Identity map already had an identity for (<class '__main__.Transactions'>, (datetime.datetime(2023, 8, 3, 15, 36, 7, 504106), 2023, 8, 3, 1), None), replacing it with newly flushed object.   Are there load operations occurring inside of an event handler within the flush?
#   session.commit()
# /tmp/ipykernel_2916490/686000837.py:63: SAWarning: Identity map already had an identity for (<class '__main__.Transactions'>, (datetime.datetime(2023, 9, 5, 15, 36, 7, 504106), 2023, 9, 5, 1), None), replacing it with newly flushed object.   Are there load operations occurring inside of an event handler within the flush?
#   session.commit()
# /tmp/ipykernel_2916490/686000837.py:63: SAWarning: Identity map already had an identity for (<class '__main__.Transactions'>, (datetime.datetime(2023, 8, 4, 15, 36, 7, 504106), 2023, 8, 4, 1), None), replacing it with newly flushed object.   Are there load operations occurring inside of an event handler within the flush?
#   session.commit()
# /tmp/ipykernel_2916490/686000837.py:63: SAWarning: Identity map already had an identity for (<class '__main__.Transactions'>, (datetime.datetime(2023, 9, 7, 15, 36, 7, 504106), 2023, 9, 7, 1), None), replacing it with newly flushed object.   Are there load operations occurring inside of an event handler within the flush?
#   session.commit()
# /tmp/ipykernel_2916490/686000837.py:63: SAWarning: Identity map already had an identity for (<class '__main__.Transactions'>, (datetime.datetime(2023, 8, 5, 15, 36, 7, 504106), 2023, 8, 5, 1), None), replacing it with newly flushed object.   Are there load operations occurring inside of an event handler within the flush?
#   session.commit()
# /tmp/ipykernel_2916490/686000837.py:63: SAWarning: Identity map already had an identity for (<class '__main__.Transactions'>, (datetime.datetime(2023, 9, 8, 15, 36, 7, 504106), 2023, 9, 8, 1), None), replacing it with newly flushed object.   Are there load operations occurring inside of an event handler within the flush?
#   session.commit()
# /tmp/ipykernel_2916490/686000837.py:63: SAWarning: Identity map already had an identity for (<class '__main__.Transactions'>, (datetime.datetime(2023, 8, 6, 15, 36, 7, 504106), 2023, 8, 6, 1), None), replacing it with newly flushed object.   Are there load operations occurring inside of an event handler within the flush?
#   session.commit()
# /tmp/ipykernel_2916490/686000837.py:63: SAWarning: Identity map already had an identity for (<class '__main__.Transactions'>, (datetime.datetime(2023, 9, 9, 15, 36, 7, 504106), 2023, 9, 9, 1), None), replacing it with newly flushed object.   Are there load operations occurring inside of an event handler within the flush?
#   session.commit()
# /tmp/ipykernel_2916490/686000837.py:63: SAWarning: Identity map already had an identity for (<class '__main__.Transactions'>, (datetime.datetime(2023, 8, 7, 15, 36, 7, 504106), 2023, 8, 7, 1), None), replacing it with newly flushed object.   Are there load operations occurring inside of an event handler within the flush?
#   session.commit()
# /tmp/ipykernel_2916490/686000837.py:63: SAWarning: Identity map already had an identity for (<class '__main__.Transactions'>, (datetime.datetime(2023, 9, 10, 15, 36, 7, 504106), 2023, 9, 10, 1), None), replacing it with newly flushed object.   Are there load operations occurring inside of an event handler within the flush?
#   session.commit()
# /tmp/ipykernel_2916490/686000837.py:63: SAWarning: Identity map already had an identity for (<class '__main__.Transactions'>, (datetime.datetime(2023, 8, 8, 15, 36, 7, 504106), 2023, 8, 8, 1), None), replacing it with newly flushed object.   Are there load operations occurring inside of an event handler within the flush?
#   session.commit()
# /tmp/ipykernel_2916490/686000837.py:63: SAWarning: Identity map already had an identity for (<class '__main__.Transactions'>, (datetime.datetime(2023, 8, 9, 15, 36, 7, 504106), 2023, 8, 9, 1), None), replacing it with newly flushed object.   Are there load operations occurring inside of an event handler within the flush?
#   session.commit()
